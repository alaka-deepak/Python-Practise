# %% [markdown]
# #### Loop in Python

# %%
# Append item to list
student="John Smith Alexander"
students=[]
students.append(student)
print(students)
# Out:
# ['John Smith Alexander']

# %%
# Capitalize the word's 1st letter

print(student.capitalize())
# Out:
# John smith alexander

# %%
### Loop
while(True):
    print("Hello") # Indefinite loop

# %%
# Change each word - capitalize
student.title()
# Out:
# 'John Smith Alexander'

# %%
password=input("Enter the password")

while password!="pass123":
    print("Login")

print("Welcome to the world of programming!")

# %%
x=1
while x<=6:
    print(x)
    x=x+1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
## print(dir(str))
# Please note that if you want to get the output of help and dir from a normal .py file, you have to use a print function, otherwise the .py file will not return any output when executed:
# print(dir(str))
# That is because the Python interactive shell uses a print function implicitly, so you don't have to type it in, but this is not the case when the code is inside .py files.

# %% [markdown]
# #### Recommended white space character used for indentation is '4'

# %% [markdown]
# #### match statement - python version of a switch-case

# %%
color="green"

match color:
    case "red":
        print("Stop")
    case "yellow":
        print("Slow down")
    case "green":
        print("Green !  ready to go")
    case _:
        print("Unknown color")
# Out:
# Green ready to go

# %% [markdown]
# ### WHAT (SURPRISINGLY) IS PYTHON?
#
# <li> Python is a language, It happens to written in C language
# <li> CPython is the software can be downloaded
# <li> python ---> want to communicate with the processor(CPython is the interpreter)
# <li>  How does the for-loop work?
#
#             The for-loop executes the indented lines n-times, where n is the number of items in the list that is being iterated.
#
# <li> What is the difference between a while loop and a for-loop?
#
#              A while loop iterates as long as the while-condition is True. A for-loop iterates that many times as there are items in the list that is being iterated.
#
# <li> What are some other examples when we would need to use a for-loop?
#
#             A for-loop is generally needed when you want to perform the same manipulation on multiple objects (e.g., capitalizing strings of a list). Another example of when you would need to use a for-loop is if you wanted to convert a video to grayscale. A video is made of hundreds or thousands of image frames. You would need to use a for-loop to iterate over the video frames and apply a grayscale effect to each frame. Another example would be to iterate over the pages of your blog website to extract their user comments, etc.
#
# <li> What is the difference between match-case and if-else?
#
#         Match-case is usually to match a string out of a predefined number of strings (e.g., a series of commands, months of the year, etc.).  If-else conditionals check more complex conditions. We will cover if-else conditionals later in the course. There you will understand the exact difference.

# %% [markdown]
# ### Manipulate the data[List,tuples]

# %%
type('z')
type(str(10.2))
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
filenames=["1.raw data.text","2.reports.txt","3.Presentation.txt"]

for filename in filenames:
    filename=filename.replace('.','-')
    print(filename)
# Out:
# 1-raw data-text
# 2-reports-txt
# 3-Presentation-txt

# %%
# Enumerate
todos=["sd","dw","dw","re","g"]
for index,item in enumerate(todos):
    print(index,item)

# %% [markdown]
# # List comprehension

# %%
usernames = ["john 1990", "alberta1970", "magnola2000"]
updated_names=[names.title() for names in usernames]
print(updated_names)
